# %% [markdown]
# # Cory Baird

# %% [markdown]
# # Problem set 4

# %% [markdown]
# # Question 1
#
# - 	Assume that labor income is zero every period, so that the agent's only resource is his financial wealth a.
# - At time t, the agent consumes part of his wealth and invests the rest.
#     - For convenience, assume that there is no portfolio choice; there is only none asset, and it is risky.  The dynamic budget constraint is thus!
#
# DBC
#
# $$a_{t+1} = (a_t- c_t) * (1+z_{t+1})$$
#
# - U(c) = log(c)

# %% [markdown]
# ## 1.a.1 Identify the state and control variables; define the value function and write down the Bellman's equation.
#
# For this problem, it turns out that the value function at time t depends only on the stock of wealth; that is, one can write:
#
# $$V_t = V(a_t)$$
#
# where V is time-invariant.
#
#
# - The solution method for this problem is "guess and verify".  First, one guesses the functional form of V(a).  Then, one solves the Bellman's equation to find the decision rule for optimal consumption assuming the guess is correct.  Finally, one plugs the decision rule for consumption back into the Bellman's equation, verifies that the original guess was correct, and solves for the parameters of V(a)
#
# In our case, our guess is that the value function takes the form:
#
# The value function takes the form:
#
# $$V(a_t)= A log(a_t) + B \tag{1}$$

# %% [markdown]
# ![Screen%20Shot%202020-09-24%20at%2012.00.27%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%2012.00.27%20PM.png)

# %% [markdown]
# ## 1.a.2 Explain why there are no other state variables that affect V?
#
# ## 1.a.2 Answer
#
# - Utility function and financial wealth are time invariant
# - State variables do not change over time

# %% [markdown]
# ## 1.a.3 what assumptions did we make to eliminate other possible state variables?

# %% [markdown]
# ## 1.a.3 Answer
#
# - $z_t$ is iid

# %% [markdown]
# ## 1.b
#
#
#
# - Plug in 1 into the Bellman's equation (be sure to plug it into both sides, with the appropriate time subscripts), and solve the maximization problem on the RHS of the Bellman's equation to find a decision rule for ct in terms of at, A, B and the model's other parameters, including the time-discount factor and the probability distribution of zt+1

# %% [markdown]
# ![Screen%20Shot%202020-09-24%20at%2012.01.32%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%2012.01.32%20PM.png)

# %% [markdown]
# ## 1.c
# - Plug the decision rule for c into the right-hand side of the Bellman's equation--be sure to plug it into both the u(c) term and into the expression for wealth at t+1--and verify that the value function at time t does indeed have the form in equation 1.
#
#
# - Solve for A in terms of the model's parameters, and plug your solution back into the decision rule for consumption from part (b) in order to express optimal ct solely in terms of at and the model's underlying parameters (not including A or B).

# %% [markdown]
# ![Screen%20Shot%202020-09-24%20at%2012.24.35%20PM.png](attachment:Screen%20Shot%202020-09-24%20at%2012.24.35%20PM.png)

# %% [markdown]
# # 2. Optimal consumption under uncertainty
#
# Consider the following problem.  People live two periods.  Their preferences over consumption in both periods as of period 1 are given by
#
# $$ln(c_1)+E_1 ln(c_2)$$
#
# - There is a single consumption good in the economy, which you can think of as apples.
#     - Apples are non-perishable; they can be stored from period 1 to period 2 with no depreciation.
#         - (In other words, it is possible to save apples, and the gross rate of return on saving is R = 1).
#         - However, apples are indivisible (or discrete).  You can eat one apple, or two apples (or more), but you can’t eat 1.5 apples.
#
# - Assume that borrowing in period 1 is not allowed.
#
#
# - People are born with an endowment a1 of apples, where a1 is some integer satisfying 0 ≤ a1 ≤ 4.
# - In addition they receive a flow income of apples yt in each period.  - People know y1 when they make their consumption/saving decision in period 1, but y2 is not realized until the following period and is thus stochastic as of period 1.
#
# - Income yt follows a two-state Markov Process with a symmetric transition matrix P2*2.  The possible realizations of y are 1 or 2 (you either get one apple or two apples each period).  The diagonal elements of P are equal to 0.8, and the off-diagonal elements are equal to 0.2.  In other words, for a given value of y1, next period’s income y2 will equal y1 with probability 0.8, and will switch to the other value with probability 0.2.

# %% [markdown]
# ## 2.a Identify the state and control variables in period 1, and write down the dynamic budget constraint.

# %% [markdown]
# ![Screen%20Shot%202020-09-28%20at%201.55.19%20PM.png](attachment:Screen%20Shot%202020-09-28%20at%201.55.19%20PM.png)

# %% [markdown]
# ## 2.b Write down the Bellman equation for the household’s problem, plugging in particular parameter values wherever possible.

# %% [markdown]
# ![Screen%20Shot%202020-09-28%20at%201.55.23%20PM.png](attachment:Screen%20Shot%202020-09-28%20at%201.55.23%20PM.png)

# %% [markdown]
# ## 2.c Solve for the value function in period 2. Solve the decision rule in period 1 and the value function in period 1, conditional on y1 = 1.

# %% [markdown]
# ![Screen%20Shot%202020-09-29%20at%207.22.23%20PM.png](attachment:Screen%20Shot%202020-09-29%20at%207.22.23%20PM.png)
